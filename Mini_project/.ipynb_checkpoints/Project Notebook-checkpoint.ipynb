# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.integrate import quad
from scipy.stats import multivariate_normal
from scipy.stats import truncnorm
from scipy.stats import norm
import scipy.integrate as integrate

# %% [markdown]
# # Functions

# %%
def pdf(x, mean, variance):
    """ One-Diemensional standard gaussian PDF """
    return (np.exp(-(x-mean)**2 / (2*variance))) * (1/(np.sqrt(2 * np.pi * variance)))

def pdf_t(t, variance, mean, y):
    """  p(t|s1,s2,y): The full conditional distribution of the outcome """
    if y==1:
        return np.where((0 < t), pdf(t, mean, variance), 0)  # return 0 if t lower than 0
    else: # y=-1
        return np.where((0 > t), pdf(t, mean, variance), 0)  # return 0 if t higher than 0
        

def plot_function(x,y):
    """ Standard 1D plotting function """
    # Create a figure and axis
    fig, ax = plt.subplots()

    # Plot the data
    ax.plot(x, y, label='PDF')

    # Set labels and title
    ax.set_xlabel('t')
    ax.set_ylabel('p(t)')
    ax.set_title('PDF')
    ax.legend()
    ax.grid(True)

    # Show the plot
    plt.show()
    
    
def prob_from_pdf(mean, variance, lower, upper):
    """ Integrate PDF within range to get probability"""
    return quad(pdf, lower, upper, args=(mean, variance))


def plot_3d_gaussian(mean_vec, variance_mat):
    """ Given a mean vector and covariance matrix generate a 3D plot of the distribution """
    # Create a grid
    x, y = np.linspace(-10, 10, 100), np.linspace(-10, 10, 100)
    x, y = np.meshgrid(x, y)
    pos = np.dstack((x, y))

    # Create a 3D Gaussian surface
    rv = multivariate_normal(mean_vec.flatten(), variance_mat)
    z = rv.pdf(pos)

    # Create the 3D plot
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(x, y, z, cmap='viridis')

    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_zlabel('Probability Density')

    plt.show()

# %% [markdown]
# ## Variables

# %%
# Mean
mu_1 = 1
mu_2 = -1

# Variances
var_1 = 1
var_2 = 4
var_t = 5

# Random Variables
s_1 = 1
s_2 = -1
t = 3

# %% [markdown]
# ## Q3

# %% [markdown]
# ###  Compute p(s1, s2|t, y)

# %% [markdown]
# p(s1, s2|t, y): the full conditional distribution of the skills
#
# Given that we know the (distribution) outcome of the match. Generate a gaussian representing the skills

# %%
#### Covariance Sigma
S_11 = var_1*(var_2+var_t) / (var_1+var_2+var_t)
S_12 = var_1*var_2 / (var_1+var_2+var_t)
S_21 = S_12
S_22 = var_2*(var_1+var_t) / (var_1+var_2+var_t)

sigma_ab = np.array([[S_11, S_12],[S_21, S_22]])
print(f"Sigma matrix:\n {sigma_ab}")


### Mean Mu
U_1 = (var_1*(t+mu_2) + mu_1*(var_2+var_t)) / (var_1+var_2+var_t)
U_2 = (var_2*(mu_1-t) + mu_2*(var_1+var_t)) / (var_1+var_2+var_t)

mu_ab = np.array([[U_1],[U_2]]) 
print(f"\nMean vector:\n {mu_ab}")



### Plot the 3D gaussian
print("\n3D-Plot:")

plot_3d_gaussian(mu_ab, sigma_ab)
# Out:
# Sigma matrix:
#  [[0.9 0.4]
#  [0.4 2.4]]
#
# Mean vector:
#  [[ 1.1]
#  [-1.4]]
#
# 3D-Plot:

# %% [markdown]
# ### Compute p(t | s1, s2, y)

# %% [markdown]
# p(t | s1, s2, y) = N(s1-s2, var_t): The full conditional distribution of the outcome
#
# Given that we know the outcome and the player skills, generate a gaussian of the distribution of the outcome

# %%
# Define variables
mu_t = s_1-s_2

# Set outcome
y=1

# Define x and y
t = np.linspace(-10,10,1000)
p = pdf_t(t, var_t, mu_t, y)

plot_function(t,p)

# %% [markdown]
# ### Compute p(y = 1)

# %% [markdown]
# Probability that player 1 wins is equal:        p(y=1) = p(t>0)
#
# Probability that player 2 wins is equal:        p(y=-1) = p(t<0)   or    1-p(y=1)

# %%
# Define mean and variance for p(t)
mean = mu_1 - mu_2
variance = var_1 + var_2 + var_t

# Range
a = 0
b = np.inf

# Integrate
integral_value, _ = prob_from_pdf(mean,variance,a,b)

# Output
print(f"Mean = {mean}")
print(f"Variance = {variance}")
print(f"Probability = {integral_value}")
# Out:
# Mean = 2
# Variance = 10
# Probability = 0.7364553715672308

# %% [markdown]
# ## Q4 - Gibbs sampler

# %% [markdown]
# ### How to compute p(s1,s2 | y)

# %% [markdown]
# Initially we know p(s1), p(s2) and y. We want to compute p(s1,s2 | y)
#
# 1. Calculate p(t | s1,s2,y) according to question 2 from Q3 (sample from truncated gaussian)
#
# 2. Calculate p(s1,s2 | t) according to question 1 from Q3

# %% [markdown]
# ### Troubleshooting and plots

# %%
### Gibbs Sampling Settings
N = 1000  # Total number of samples
B = N//5    # Burn-in

### Match setting 
y = 1 # player 1 wins

### Initiating player skills: Same hyperparameters for p(s1) and p(s2)
# Player 1
mean_s1 = 25
var_s1 = (25/3)
std_s1 = np.sqrt(var_s1)
# Player 2
mean_s2 = mean_s1
var_s2 = var_s1
std_s2 = std_s1
# Estimate variance of game
var_t = 4.167


### Initial values
s1_samples = np.zeros(N)
s2_samples = np.zeros(N)
s1_samples[0] = np.random.normal(mean_s1, std_s1) 
s2_samples[0] = np.random.normal(mean_s2, std_s2) 


############################## Gibbs sampling ############################## 
for i in range(N-1): 
    ### Sample from p(t | s1,s2,y)
    mean_t = s1_samples[i] - s2_samples[i]

    if y==1:
        lower_bound = -mean_t/np.sqrt(var_t)# truncate from 0 expressed in terms of std
        upper_bound = np.inf
    elif y==-1:
        lower_bound = -np.inf
        upper_bound = -mean_t/np.sqrt(var_t)# truncate from 0 expressed in terms of std
    
    t_sample = truncnorm.rvs(lower_bound, upper_bound, loc=mean_t, scale=np.sqrt(var_t))

    
    ### Sample from p(s1,s2 | t) 
    # Covariance matrix
    S_11 = var_s1*(var_s2+var_t) / (var_s1+var_s2+var_t)
    S_12 = var_s1*var_s2 / (var_s1+var_s2+var_t)
    S_21 = S_12
    S_22 = var_s2*(var_s1+var_t) / (var_s1+var_s2+var_t)
    covar_mat = np.array([[S_11, S_12],[S_21, S_22]])

    # Mean vector
    U_1 = (var_s1*(t_sample+mean_s2) + mean_s1*(var_s2+var_t)) / (var_s1+var_s2+var_t)
    U_2 = (var_s2*(mean_s1-t_sample) + mean_s2*(var_s1+var_t)) / (var_s1+var_s2+var_t)
    mean_vec = np.array([[U_1],[U_2]]) 
    
    # Draw sample of s1 and s2
    s1_sample, s2_sample = np.random.multivariate_normal(mean_vec.flatten(), covar_mat, 1).T
    
    s1_samples[i+1] = s1_sample
    s2_samples[i+1] = s2_sample

    

############################## Determine burn-in ############################## 
plt.plot(s1_samples,label="S1")
plt.plot(s2_samples,label="S2")
plt.title("Determine burn-in")
plt.grid()
plt.legend()
plt.show()
    
# Discard burn-in
final_s1_samples = s1_samples[B:]
final_s2_samples = s2_samples[B:]
       
    
    
    
    
############################## Plot Histogram of Gibbs sampling ############################## 
plt.hist(final_s1_samples,bins=100, alpha=0.8,label="S1")
plt.hist(final_s2_samples,bins=100, alpha=0.8,label="S2")
plt.title("Histogram from Gibbs")
plt.legend()
plt.show()



    
    
############################## Plot PDFs before and after sampling ############################## 
xv = np.linspace(0,50,100)
plt.plot(xv, 1 / (std_s1 * np.sqrt(2 * np.pi)) * np.exp(-.5 * ((xv - mean_s1) / std_s1) ** 2), label="S1 and S2 org")  
#plt.plot(xv, 1 / (std_s2 * np.sqrt(2 * np.pi)) * np.exp(-.5 * ((xv - mean_s2) / std_s2) ** 2), label="S2 org")

# Print and update posterior mean and variance
post_mean_s1 = np.mean(final_s1_samples)
post_var_s1 = np.var(final_s1_samples)
post_mean_s2 = np.mean(final_s2_samples)
post_var_s2 = np.var(final_s2_samples)

plt.plot(xv, 1 / (std_s1 * np.sqrt(2 * np.pi)) * np.exp(-.5 * ((xv - post_mean_s1) / std_s1) ** 2), label="S1 update", linestyle='--')  
plt.plot(xv, 1 / (std_s2 * np.sqrt(2 * np.pi)) * np.exp(-.5 * ((xv - post_mean_s2) / std_s2) ** 2), label="S2 update", linestyle='--')
plt.xlim(0,50)

plt.title("Player Skills as PDF")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Complete function

# %%
def gibbs_sampling(S1,S2,y,N,B):
    """ 
    Input:
        S1 is dictionary for player 1
        S2 is dictionary for player 2
        y is outcome of match
        N is how many samples to take
        B is burn_in index
        
    Return:
        Updated S1 dictionary
        Updated S2 dicitonary
    """
    ### Approximate variance for t  HYPERPARAMETER
    var_t = 4.167
    
    ### Extract values from dicts
    mean_s1, var_s1 = S1["mean"], S1["variance"]
    mean_s2, var_s2 = S2["mean"], S2["variance"]
    std_s1, std_s2 = np.sqrt(var_s1), np.sqrt(var_s2)
    

    ### Sample initial values for s1 and s2
    s1_samples, s2_samples = np.zeros(N), np.zeros(N)
    s1_samples[0], s2_samples[0] = np.random.normal(mean_s1, std_s1), np.random.normal(mean_s2, std_s2) 

    ############################## Gibbs sampling ############################## 
    for i in range(N-1): 
        ### Sample from p(t | s1,s2,y)
        mean_t = s1_samples[i] - s2_samples[i]
        
        if y==1:
            lower_bound = -mean_t/np.sqrt(var_t)# truncate from 0 expressed in terms of std
            upper_bound = np.inf
        elif y==-1:
            lower_bound = -np.inf
            upper_bound = -mean_t/np.sqrt(var_t)# truncate from 0 expressed in terms of std

        t_sample = truncnorm.rvs(lower_bound, upper_bound, loc=mean_t, scale=np.sqrt(var_t))
        
        
        ### Sample from p(s1,s2 | t) 
        # Covariance matrix
        S_11 = var_s1*(var_s2+var_t) / (var_s1+var_s2+var_t)
        S_12 = var_s1*var_s2 / (var_s1+var_s2+var_t)
        S_21 = S_12
        S_22 = var_s2*(var_s1+var_t) / (var_s1+var_s2+var_t)
        covar_mat = np.array([[S_11, S_12],[S_21, S_22]])

        # Mean vector
        U_1 = (var_s1*(t_sample+mean_s2) + mean_s1*(var_s2+var_t)) / (var_s1+var_s2+var_t)
        U_2 = (var_s2*(mean_s1-t_sample) + mean_s2*(var_s1+var_t)) / (var_s1+var_s2+var_t)
        mean_vec = np.array([[U_1],[U_2]]) 

        # Draw sample of s1 and s2
        s1_sample, s2_sample = np.random.multivariate_normal(mean_vec.flatten(), covar_mat, 1).T
        s1_samples[i+1] = s1_sample
        s2_samples[i+1] = s2_sample
    
    ### Discard burn-in
    final_s1_samples = s1_samples[B:]
    final_s2_samples = s2_samples[B:]

    ### Update player dictionaries
    S1["mean"] = np.mean(final_s1_samples)
    S1["variance"] = np.var(final_s1_samples)
    S2["mean"] = np.mean(final_s2_samples)
    S2["variance"] = np.var(final_s2_samples)
    
    return S1, S2, final_s1_samples, final_s2_samples

# %% [markdown]
# ### Test Gibbs

# %%
### Match setup
S1 = {"mean": 25, "variance": (25/3)}
S2 = {"mean": 25, "variance": (25/3)}
y = 1 # who wins
N = 10000
B = 500

S1, S2,_,_ = gibbs_sampling(S1,S2,y,N,B)

print("S1:")
print(f"   Updated Mean: {S1['mean']}")
print(f"   Updated Variance: {S1['variance']}")
print("S2:")
print(f"   Updated Mean: {S2['mean']}")
print(f"   Updated Variance: {S2['variance']}")
# Out:
# S1:
#    Updated Mean: 26.458686872269027
#    Updated Variance: 6.142968734716417
# S2:
#    Updated Mean: 23.541148510210846
#    Updated Variance: 6.1416321776180345

# %% [markdown]
# # Q5

# %%
#################### Read data #################### 
df = pd.read_csv('SerieA_1819.csv')

print(df.head())
print(df.size)
# Out:
#    yyyy-mm-dd  HH:MM     team1     team2  score1  score2
# 0  2018-08-18  18:00    Chievo  Juventus       2       3
# 1  2018-08-18  20:30     Lazio    Napoli       1       2
# 2  2018-08-19  18:00    Torino      Roma       0       1
# 3  2018-08-19  20:30  Sassuolo     Inter       1       0
# 4  2018-08-19  20:30     Parma   Udinese       2       2
# 2280

# %%
####################  Preprocess data #################### 
# Drop columns with no relevant info
df.drop(['yyyy-mm-dd', 'HH:MM'], axis=1, inplace=True)

# Drop rows where game is even
df = df[df['score1'] != df['score2']]

print(df.head())
print(df.size)
# Out:
#       team1     team2  score1  score2
# 0    Chievo  Juventus       2       3
# 1     Lazio    Napoli       1       2
# 2    Torino      Roma       0       1
# 3  Sassuolo     Inter       1       0
# 5    Empoli  Cagliari       2       0
# 1088

# %%
#################### Find unique teams and create list of dictionaries ####################
unique_teams = pd.concat([df['team1'], df['team2']]).drop_duplicates().tolist()

# Initiate
initial_mean = 25
initial_variance = (25/3)

def initiate_teams(initial_mean, initial_variance):
    team_dicts = {}
    for team in unique_teams:
        team_dicts[team] = {
            'mean': initial_mean,
            'variance': initial_variance
        }
    return team_dicts

team_dicts = initiate_teams(initial_mean, initial_variance)

# %%
#################### Apply gibbs sampler to all games ####################

# Constants for Gibbs Sampling
N = 2500  # Number of samples
B = N//5  # Burn-in index

# Iterate through each game (row) in DataFrame
for index, row in df.iterrows():
    team1 = row['team1']
    team2 = row['team2']
    score1 = row['score1']
    score2 = row['score2']
    
    # Determine the outcome 'y'
    if score1 > score2:
        y = 1
    elif score1 < score2:
        y = -1
    
    # Update skill levels using Gibbs sampling
    team_dicts[team1], team_dicts[team2] = gibbs_sampling(team_dicts[team1], team_dicts[team2], y, N, B)

# %% [markdown]
# ### Visualize results

# %%
# Sort the teams by their mean value
sorted_teams = sorted(team_dicts.items(), key=lambda x: x[1]['mean'],reverse=True)

# Print sorted teams and their mean values
for team, stats in sorted_teams:
    print(f"{team}: {np.round(stats['mean'],2)}")
# Out:
# Juventus: 39.54
# Napoli: 33.07
# Torino: 32.38
# Inter: 30.9
# Milan: 28.66
# Roma: 26.77
# Lazio: 26.3
# Atalanta: 25.96
# Sampdoria: 24.15
# Cagliari: 23.54
# Empoli: 23.32
# Sassuolo: 22.73
# Genoa: 20.56
# Bologna: 20.02
# Spal: 19.7
# Parma: 18.45
# Fiorentina: 18.22
# Udinese: 18.11
# Frosinone: 11.28
# Chievo: 10.09

# %%
plt.figure(figsize=(12, 8))

for team in team_dicts.keys():
    mean = team_dicts[team]['mean']
    std_dev = np.sqrt(team_dicts[team]['variance'])
    x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)
    plt.plot(x, norm.pdf(x, mean, std_dev), label=team)

plt.title('Skill Levels of All Teams')
plt.xlabel('Skill Level')
plt.ylabel('Probability Density')
plt.legend()
plt.grid()
plt.savefig("team_skill_levels_1.png")
plt.show()

# %% [markdown]
# ### Changing the order of matches

# %%
# Initiate
initial_mean = 25
initial_variance = (25/3)

team_dicts = initiate_teams(initial_mean, initial_variance)


#################### Apply gibbs sampler to all games ####################

# Constants for Gibbs Sampling
N = 2500  # Number of samples
B = N//5  # Burn-in index

# Shuffle dataframe
df = df.sample(frac=1).reset_index(drop=True)

# Iterate through each game (row) in DataFrame
for index, row in df.iterrows():
    team1 = row['team1']
    team2 = row['team2']
    score1 = row['score1']
    score2 = row['score2']
    
    # Determine the outcome 'y'
    if score1 > score2:
        y = 1
    elif score1 < score2:
        y = -1
    
    # Update skill levels using Gibbs sampling
    team_dicts[team1], team_dicts[team2] = gibbs_sampling(team_dicts[team1], team_dicts[team2], y, N, B)

    
# Sort the teams by their mean value
sorted_teams = sorted(team_dicts.items(), key=lambda x: x[1]['mean'],reverse=True)

# Print sorted teams and their mean values
for team, stats in sorted_teams:
    print(f"{team}: {np.round(stats['mean'],2)}")
# Out:
# Juventus: 27.46
# Napoli: 26.34
# Milan: 26.26
# Roma: 26.16
# Torino: 25.93
# Inter: 25.87
# Atalanta: 25.69
# Lazio: 25.11
# Sampdoria: 24.81
# Bologna: 24.77
# Spal: 24.4
# Genoa: 24.31
# Sassuolo: 24.22
# Empoli: 24.04
# Cagliari: 23.99
# Udinese: 23.97
# Parma: 23.94
# Fiorentina: 23.82
# Frosinone: 22.71
# Chievo: 21.5

# %% [markdown]
# # Q6

# %% [markdown]
# We want a deterministic way of predicting which team will win each game so no sampling should be used.
#
#
# The probability of team 1 winning is equal to the probability that the distribution of the outcome is greater than 0: p(y=1) == p(t>0)

# %%
def predict_outcome(S1,S2):
    """
    Formula derived in last part of Q3
    """
    # HYPERPARAMETER
    var_t = 4.167
    
    ### Calculate mean and variance
    mean_t = S1["mean"]-S2["mean"]
    variance = S1["variance"]+S2["variance"]+var_t  

    ### Integrate to get probability
    prob_1, _ = integrate.quad(lambda x: norm.pdf(x, mean_t, var_t ** 0.5), 0, float('inf'))
    prob_2 = 1-prob_1

    ### Which is more likely
    if prob_1 > prob_2:
        return 1 # team 1 wins
    else:
        return -1 # team 2 wins

# %%
### Initiate all teams equally
team_dicts = initiate_teams(initial_mean=20, initial_variance=5)

### Gibbs settings
N = 2500  # Number of samples
B = N//5  # Burn-in index


### Find model performance
correct = 0
random_correct = 0
total_games = len(df)
for index, row in df.iterrows():
    team1 = row['team1']
    team2 = row['team2']
    score1 = row['score1']
    score2 = row['score2']
    
    # Make prediction
    outcome = predict_outcome(team_dicts[team1],team_dicts[team2])
    
    # Determine the outcome 'y'
    if score1 > score2:
        y = 1
    elif score1 < score2:
        y = -1
        
    # Check model prediction against random
    if outcome == y:
        correct+=1
    if np.random.choice([-1,1]) == y:
        random_correct+=1
    
    # Update skill levels using Gibbs sampling
    team_dicts[team1], team_dicts[team2] = gibbs_sampling(team_dicts[team1], team_dicts[team2], y, N, B)
    
print(f"Correctly predicted: {100*np.round((correct/total_games),3)}%")
print(f"Random correct: {100*np.round((random_correct/total_games),3)}%")
# Out:
# Correctly predicted: 66.9%
# Random correct: 49.3%

# %% [markdown]
# # Q7

# %% [markdown]
# Derived on paper and in the report

# %% [markdown]
# # Q8

# %% [markdown]
# ### Functions

# %%
# Function for multiplying Gaussians
def multiply_gaussians(m1, s1, m2, s2):
    s = 1 / (1 / s1 + 1 / s2)
    m = (m1 / s1 + m2 / s2) * s
    return m, s

# Function for dividing Gaussians
def divide_gaussians(m1, s1, m2, s2):
    m, s = multiply_gaussians(m1, s1, m2, -s2)
    return m, s

# Function for truncated Gaussian moment matching
def trunc_gauss_mm(a, b, m0, s0):
    a_scaled, b_scaled = (a - m0) / np.sqrt(s0), (b - m0) / np.sqrt(s0)
    m = truncnorm.mean(a_scaled, b_scaled, loc=m0, scale=np.sqrt(s0))
    s = truncnorm.var(a_scaled, b_scaled, loc=m0, scale=np.sqrt(s0))
    return m, s


def message_passing(S1,S2,y):
    ### Hyperparameter
    var_t = 4.167
    
    ################# Message-passing from S1 and S2 to t #################
    # Message-passing from f1->s1 and f2->s2
    mu_f1_s1_mean, mu_f1_s1_variance = S1['mean'], S1['variance']
    mu_f2_s2_mean, mu_f2_s2_variance = S2['mean'], S2['variance']

    # Message-passing from s1->f3 and s2->f3
    mu_s1_f3_mean, mu_s1_f3_variance = mu_f1_s1_mean, mu_f1_s1_variance
    mu_s2_f3_mean, mu_s2_f3_variance = mu_f2_s2_mean, mu_f2_s2_variance

    # Compute at f3
    f3_mean = mu_s1_f3_mean-mu_s2_f3_mean
    f3_variance = mu_s1_f3_variance + mu_s2_f3_variance + var_t

    # Message passing from f3->t
    mu_f3_t_mean, mu_f3_t_variance = f3_mean, f3_variance


    ################# MOMENT MATCHING TO APPROXIMATE p(t|y) #################
    # Find truncation bounds  (these are scaled in the trunc_gauss_mm function)
    if y == 1:
        a, b = 0, np.inf
    else:
        a, b = -np.inf, 0

    # truncate to get p(t|y)
    pt_m, pt_s = trunc_gauss_mm(a, b, mu_f3_mean, mu_f3_variance)  


    ################# BACKWARD MESSAGE PASSING FROM t TO S1 AND S2 #################
    # Backward Message-Passing from t to f3
    mu_t_f3_mean, mu_t_f3_variance = divide_gaussians(pt_m, pt_s, mu_f3_mean, mu_f3_variance)

    # Backward Message-Passing to from f3 to S1 and S2
    mu_f3_s1_mean = mu_t_f3_mean + mu_s2_f3_mean
    mu_f3_s1_variance = mu_t_f3_variance + mu_s2_f3_variance + var_t

    mu_f3_s2_mean =  mu_s1_f3_mean - mu_t_f3_mean
    mu_f3_s2_variance = mu_t_f3_variance + mu_s1_f3_variance + var_t

    
    ################# UPDATE S! and S2 #################
    # Calculate new means and variances for S1 and S2
    S1["mean"], S1["variance"] = multiply_gaussians(mu_f1_s1_mean, mu_f1_s1_variance, mu_f3_s1_mean, mu_f3_s1_variance)
    S2["mean"], S2["variance"] = multiply_gaussians(mu_f2_s2_mean, mu_f2_s2_variance, mu_f3_s2_mean, mu_f3_s2_variance)
    
    
    return S1, S2
    
    
def initiate_S1_S2():
    S1 = {"mean": 25, "variance": (25/3)}
    S2 = {"mean": 25, "variance": (25/3)}
    
    return S1,S2

# %%
### Initialize parameters and setup
y = 1 # Which player is winner
N = 10000
B = 500


### Gibbs sampling
S1,S2 = initiate_S1_S2()
S1_gibbs, S2_gibbs, S1_samples, S2_samples = gibbs_sampling(S1,S2,y,N,B)

### Message passing
S1,S2 = initiate_S1_S2()
S1_mp, S2_mp = message_passing(S1,S2,y)


### PLOTS
# Initialize handles and labels for the legend
handles = []
labels = []

# Plot gibbs histogram
hist_s1 = plt.hist(S1_samples, bins=100, alpha=0.3, density=True, label="S1 samples", color="skyblue")
hist_s2 = plt.hist(S2_samples, bins=100, alpha=0.3, density=True, label="S2 samples", color="lightgreen")
handles.extend([hist_s1[2][0], hist_s2[2][0]])
labels.extend(["S1 samples", "S2 samples"])

# Plot gibbs posterior
plt.xlim(10,40)
line_s1_gibbs, = plt.plot(xv, 1 / (np.sqrt(S1_gibbs["variance"]) * np.sqrt(2 * np.pi)) * np.exp(-.5 * ((xv - S1_gibbs["mean"]) / np.sqrt(S1_gibbs["variance"])) ** 2), linestyle='--', color="dodgerblue")  
line_s2_gibbs, = plt.plot(xv, 1 / (np.sqrt(S2_gibbs["variance"]) * np.sqrt(2 * np.pi)) * np.exp(-.5 * ((xv - S2_gibbs["mean"]) / np.sqrt(S2_gibbs["variance"])) ** 2), linestyle='--', color="forestgreen")
handles.extend([line_s1_gibbs, line_s2_gibbs])
labels.extend(["S1 Gibbs update", "S2 Gibbs update"])

# Plot message passing posterior
line_s1_mp, = plt.plot(xv, 1 / (np.sqrt(S1_mp["variance"]) * np.sqrt(2 * np.pi)) * np.exp(-.5 * ((xv - S1_mp["mean"]) / np.sqrt(S1_mp["variance"])) ** 2), linestyle=':', color="darkblue")  
line_s2_mp, = plt.plot(xv, 1 / (np.sqrt(S2_mp["variance"]) * np.sqrt(2 * np.pi)) * np.exp(-.5 * ((xv - S2_mp["mean"]) / np.sqrt(S2_mp["variance"])) ** 2), linestyle=':', color="darkgreen")
handles.extend([line_s1_mp, line_s2_mp])
labels.extend(["S1 MP update", "S2 MP update"])

# Plot prior
S1,S2 = initiate_S1_S2()
line_prior, = plt.plot(xv, 1 / (np.sqrt(S1["variance"]) * np.sqrt(2 * np.pi)) * np.exp(-.5 * ((xv - S1["mean"]) / np.sqrt(S1["variance"])) ** 2), linestyle='--', color="gray")
handles.append(line_prior)
labels.extend("Prior")

# Order labels
ordered_handles = [line_prior, hist_s1[2][0], line_s1_gibbs, line_s1_mp, hist_s2[2][0], line_s2_gibbs, line_s2_mp]
ordered_labels = ["Prior", "S1 samples", "S1 Gibbs update", "S1 MP update", "S2 samples", "S2 Gibbs update", "S2 MP update"]
plt.legend(ordered_handles, ordered_labels)


plt.savefig("Gibbs_MP_Update.svg")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/fy/1nz0l06n0l74kkgf3y8k_fk40000gn/T/ipykernel_72721/1373281097.py in <module>
#      33
#      34 # Plot message passing posterior
# ---> 35 line_s1_mp, = plt.plot(xv, 1 / (np.sqrt(S1_mp["variance"]) * np.sqrt(2 * np.pi)) * np.exp(-.5 * ((xv - S1_mp["mean"]) / np.sqrt(S1_mp["variance"])) ** 2), linestyle='..', color="darkblue")
#      36 line_s2_mp, = plt.plot(xv, 1 / (np.sqrt(S2_mp["variance"]) * np.sqrt(2 * np.pi)) * np.exp(-.5 * ((xv - S2_mp["mean"]) / np.sqrt(S2_mp["variance"])) ** 2), linestyle='..', color="darkgreen")
#      37 handles.extend([line_s1_mp, line_s2_mp])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     537             return list(result)
#     538         else:
# --> 539             return [l[0] for l in result]
#     540
#     541
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#     537             return list(result)
#     538         else:
# --> 539             return [l[0] for l in result]
#     540
#     541
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in <genexpr>(.0)
#     530             labels = [label] * n_datasets
#     531
# --> 532         result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     533                               {**kwargs, 'label': label})
#     534                   for j, label in enumerate(labels))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     352         default_dict = self._getdefaults(set(), kw)
#     353         self._setdefaults(default_dict, kw)
# --> 354         seg = mlines.Line2D(x, y, **kw)
#     355         return seg, kw
#     356
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     368
#     369         self.set_linewidth(linewidth)
# --> 370         self.set_linestyle(linestyle)
#     371         self.set_drawstyle(drawstyle)
#     372
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/lines.py in set_linestyle(self, ls)
#    1144                 ls = 'None'
#    1145
# -> 1146             _api.check_in_list([*self._lineStyles, *ls_mapper_r], ls=ls)
#    1147             if ls not in self._lineStyles:
#    1148                 ls = ls_mapper_r[ls]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/__init__.py in check_in_list(_values, _print_supported_values, **kwargs)
#     124         if val not in values:
#     125             if _print_supported_values:
# --> 126                 raise ValueError(
#     127                     f"{val!r} is not a valid value for {key}; "
#     128                     f"supported values are {', '.join(map(repr, values))}")
#
# ValueError: '..' is not a valid value for ls; supported values are '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'

# %% [markdown]
# # Q9

# %% [markdown]
# # Q10

# %% [markdown]
# Extended dataset:
#
#
# • SerieA_1819.csv       ->   Data from 2018 to 2019
#
# • SerieA_extended.csv   ->   Data from 2009 to 2019
#
# • SerieA_extended_2.csv ->   Data from 2017 to 2019
#
# • SerieA_extended_3.csv ->   Data from 2016 to 2019

# %%
#################### Read data #################### 
df_ext = pd.read_csv('SerieA_extended_2.csv')

####################  Preprocess data #################### 
# Drop columns with no relevant info
df_ext.drop(['yyyy-mm-dd', 'HH:MM'], axis=1, inplace=True)

# Drop rows where game is even
df_ext = df_ext[df_ext['score1'] != df_ext['score2']]

### Initiate all teams equally
team_dicts = initiate_teams(initial_mean=25, initial_variance=(25/3))

### Gibbs settings
N = 1000  # Number of samples
B = N//5  # Burn-in index


### Find model performance
correct = 0
random_correct = 0
total_games = len(df_ext)
for index, row in df_ext.iterrows():
    team1 = row['team1']
    team2 = row['team2']
    score1 = row['score1']
    score2 = row['score2']
    
    # Make prediction
    outcome = predict_outcome(team_dicts[team1],team_dicts[team2])
    
    # Determine the outcome 'y'
    if score1 > score2:
        y = 1
    elif score1 < score2:
        y = -1
        
    # Check model prediction against random
    if outcome == y:
        correct+=1
    if np.random.choice([-1,1]) == y:
        random_correct+=1
    
    # Update skill levels using Gibbs sampling
    team_dicts[team1], team_dicts[team2] = gibbs_sampling(team_dicts[team1], team_dicts[team2], y, N, B)

    
print(f"Correctly predicted: {100*np.round((correct/total_games),3)}%")
print(f"Random correct: {100*np.round((random_correct/total_games),3)}%")
# Out:
# Correctly predicted: 36.0%
# Random correct: 31.2%
